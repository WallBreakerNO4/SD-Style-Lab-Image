# %%
from libs import stable_diffusion_service
from PIL import Image
from IPython.display import display

STABLE_DIFFUSION_BASE_URL = "http://100.119.72.3:7860"

SD = stable_diffusion_service.StableDiffusion(STABLE_DIFFUSION_BASE_URL)

# %%
image_prams = {
    "prompt": r'1girl,archetto \(arknights\),arknights,nsfw,solo,chyoel,solar \(happymonk\),[kuzuvine],[[dino \(dinoartforame\)]],[[[ciloranko]]],ask \(askzy\),penis,1boy,long hair,1girl,oral,nun,fellatio,nipples,hetero,from side,cum,breasts,habit,closed eyes,own hands clasped,upper body,solo focus,testicles,interlocked fingers,profile,cum in mouth,paizuri,small breasts,erection,hair between eyes,bow,blush,veil,saliva,ejaculation,(((glory hole))),topless,deep throat,masterpiece,high score,great score,absurdres,year 2025,',
    "negative_prompt": r'text,watermark,bad anatomy,bad proportions,extra limbs,extra digit,extra legs,extra legs and arms,disfigured,missing arms,too many fingers,fused fingers,missing fingers,unclear eyes,watermark,username,logo,artist logo,patreon logo,weibo logo,arknights logo,(latex:1.5),head out of frame,',
    "width": 832,
    "height": 1216,
    "cfg_scale": 5,
    "steps": 28,
    "sampler_name": "Euler a",
    "seed": -1,
    "batch_size": 2,
}
image = SD.generate_image(image_prams)
# Out:
# {'images': ['...', '...'], 'parameters': {'prompt': '1girl,archetto \\(arknights\\),arknights,nsfw,solo,chyoel,solar \\(happymonk\\),[kuzuvine],[[dino \\(dinoartforame\\)]],[[[ciloranko]]],ask \\(askzy\\),penis,1boy,long hair,1girl,oral,nun,fellatio,nipples,hetero,from side,cum,breasts,habit,closed eyes,own hands clasped,upper body,solo focus,testicles,interlocked fingers,profile,cum in mouth,paizuri,small breasts,erection,hair between eyes,bow,blush,veil,saliva,ejaculation,(((glory hole))),topless,deep throat,masterpiece,high score,great score,absurdres,year 2025,', 'negative_prompt': 'text,watermark,bad anatomy,bad proportions,extra limbs,extra digit,extra legs,extra legs and arms,disfigured,missing arms,too many fingers,fused fingers,missing fingers,unclear eyes,watermark,username,logo,artist logo,patreon logo,weibo logo,arknights logo,(latex:1.5),head out of frame,', 'styles': None, 'seed': -1, 'subseed': -1, 'subseed_strength': 0, 'seed_resize_from_h': -1, 'seed_resize_from_w': 
# ...
